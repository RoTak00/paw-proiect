# %%
# background removal
# %pip install onnxruntime
# %pip install rembg
# Out:
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=pyyaml-5.1-cp312-cp312-linux_x86_64.whl size=44083 sha256=224815660956d59ccb0bdd9e80e898409127bf4bf6f298f169df2675a4da9f2b
#   Stored in directory: /home/littlecloud/.cache/pip/wheels/77/56/3d/ecbc52138290af7ae8703dabe02cede143ab9cea349cf1aef3
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
# Successfully installed pyyaml-5.1
# fatal: destination path 'detectron2' already exists and is not an empty directory.
# Ignoring dataclasses: markers 'python_version < "3.7"' don't match your environment
# Requirement already satisfied: Pillow>=7.1 in ./.venv/lib64/python3.12/site-packages (11.2.1)
# Requirement already satisfied: matplotlib in ./.venv/lib64/python3.12/site-packages (3.10.3)
# Collecting pycocotools>=2.0.2
#   Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: termcolor>=1.1 in ./.venv/lib64/python3.12/site-packages (3.1.0)
# Requirement already satisfied: yacs>=0.1.8 in ./.venv/lib64/python3.12/site-packages (0.1.8)
# Requirement already satisfied: tabulate in ./.venv/lib64/python3.12/site-packages (0.9.0)
# Collecting cloudpickle
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tqdm>4.29.0 in ./.venv/lib64/python3.12/site-packages (4.67.1)
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in ./.venv/lib64/python3.12/site-packages (0.1.5.post20221221)
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Collecting omegaconf<2.4,>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black
#   Using cached black-25.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
# Requirement already satisfied: packaging in ./.venv/lib64/python3.12/site-packages (25.0)
# Requirement already satisfied: numpy in ./.venv/lib64/python3.12/site-packages (from fvcore<0.1.6,>=0.1.5) (2.2.5)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib64/python3.12/site-packages (from fvcore<0.1.6,>=0.1.5) (5.1)
# Requirement already satisfied: portalocker in ./.venv/lib64/python3.12/site-packages (from iopath<0.1.10,>=0.1.7) (3.1.1)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<2.4,>=2.1)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib64/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib64/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib64/python3.12/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib64/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib64/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib64/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Collecting absl-py>=0.4 (from tensorboard)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in ./.venv/lib64/python3.12/site-packages (from tensorboard) (6.30.2)
# Requirement already satisfied: setuptools>=41.0.0 in ./.venv/lib64/python3.12/site-packages (from tensorboard) (80.4.0)
# Requirement already satisfied: six>1.9 in ./.venv/lib64/python3.12/site-packages (from tensorboard) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting click>=8.0.0 (from black)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.4.3 (from black)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in ./.venv/lib64/python3.12/site-packages (from black) (4.3.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib64/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 15.6 MB/s eta 0:00:0031m19.9 MB/s eta 0:00:01
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 22.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Downloading black-25.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.6 MB/s eta 0:00:00
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 19.9 MB/s eta 0:00:0031m23.0 MB/s eta 0:00:01
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (pyproject.toml) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144128 sha256=7b7016e6dfeddfb35e20b2b57d34e4fccfb879ee3701df6c6289cb52d560596f
#   Stored in directory: /home/littlecloud/.cache/pip/wheels/1f/be/48/13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, werkzeug, tensorboard-data-server, pathspec, omegaconf, mypy-extensions, markdown, iopath, grpcio, cloudpickle, click, absl-py, tensorboard, hydra-core, black, pycocotools
#   Attempting uninstall: iopath━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [markdown]]kzeug]
#     Found existing installation: iopath 0.1.10m╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [markdown]
#     Uninstalling iopath-0.1.10:━╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [markdown]
#       Successfully uninstalled iopath-0.1.1037m╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [markdown]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [pycocotools]m 14/16 [black][hydra-core]
# Successfully installed absl-py-2.2.2 antlr4-python3-runtime-4.9.3 black-25.1.0 click-8.1.8 cloudpickle-3.1.1 grpcio-1.71.0 hydra-core-1.3.2 iopath-0.1.9 markdown-3.8 mypy-extensions-1.1.0 omegaconf-2.3.0 pathspec-0.12.1 pycocotools-2.0.8 tensorboard-2.19.0 tensorboard-data-server-0.7.2 werkzeug-3.1.3

# %%
# contour detection v1
# %pip install opencv-python

# %%
# counter detection
# !python -m pip install pyyaml==5.1
import sys, os, distutils.core
# Note: This is a faster way to install detectron2 in Colab, but it does not include all functionalities (e.g. compiled operators).
# See https://detectron2.readthedocs.io/tutorials/install.html for full installation instructions
# !git clone 'https://github.com/facebookresearch/detectron2'
dist = distutils.core.run_setup("./detectron2/setup.py")
# !python -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])}
sys.path.insert(0, os.path.abspath('./detectron2'))

# %%
# face detection
# %pip install tensorflow
# %pip install mtcnn
# %pip install tf-keras
# %pip install retina-face

# %%
# text recognition
# %pip install easyocr
